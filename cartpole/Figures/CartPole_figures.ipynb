# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import csv
import numpy as np

# %%
mpl.style.use('default')
cmap = plt.get_cmap("tab10")

# %%
# fig = plt.figure(figsize=(2,5))

# ax = fig.add_subplot(1,1,1)
# ax.set_title("KEY", size = 16)
# ax.axis('off')

# ax.bar(1 , 100, color='dodgerblue', alpha = 0.3, edgecolor = 'black', capsize=7,width=0.5 )
# ax.bar(1 , 60,  color='dodgerblue', alpha = 0.5,  edgecolor = 'black', capsize=7 ,width=0.5)
# ax.bar(1 , 20,  color='dodgerblue', alpha = 0.1,edgecolor = 'black', capsize=7,width=0.5 )

# ax.text(1,10,"MINIMUM VALUE",horizontalalignment='center', size = 11 )
# ax.text(1,40,"AVERAGE VALUE",horizontalalignment='center', size = 11 )
# ax.text(1,80,"MAXIMUM VALUE",horizontalalignment='center', size = 11 )

# ax.set_xticks([])
# ax.set_xticklabels([])
# ax.set_yticks([])
# ax.set_yticklabels([])
# fig.savefig('key.pdf', bbox_inches='tight')

# %%
EPISODES = np.array([1993.47,2416.97,2380.12,1083,938,794,832])

# TIMESTEPS
NN = np.array([73513,159101.15,388725])
NN_R =np.array([89662,179874.31,274620]) 
NN_L =np.array([52715,415927.76,1382621])
DRL = np.array([476,1921.21,5568])
DRL_XPLORE = np.array([604,1731.14,4847])
DRL_CP = np.array([455,1457.71,3533])
DRL_XPLORE_CP = np.array([617,1618.74,3594])

DATA = np.vstack((NN, NN_R, NN_L, DRL, DRL_XPLORE, DRL_CP, DRL_XPLORE_CP))
NO_OF_DATA_GRPS = DATA.shape[0] 

MIN_VALUE = DATA[:,0]
AVG_VALUE = DATA[:,1]
MAX_VALUE = DATA[:,2]

fig = plt.figure(figsize = (7,5))

ax = fig.add_subplot(1, 1, 1)
ax.set_title("CartPole-v0 Environment", size = 22)
ax.bar(range(NO_OF_DATA_GRPS) , MAX_VALUE,  alpha = 0.5, edgecolor = 'black', capsize=7,label = "Maximum Time Required" )
ax.bar(range(NO_OF_DATA_GRPS) , AVG_VALUE,  edgecolor = 'black', capsize=7 ,label = "Average Time Required")
ax.bar(range(NO_OF_DATA_GRPS) , MIN_VALUE,  alpha = 0.6,edgecolor = 'black', capsize=7, label = "Minimum Time Required") 

ax.set_xticks(range(NO_OF_DATA_GRPS))
ax.set_xticklabels(["NN", "NN-R", "NN-L", "DRL", "DRL-XPLR", "DRL-CP", "DRL-XCP" ],rotation=30, size = 14)


for i in range(NO_OF_DATA_GRPS):
    ax.text(x = 0.05+i/7.5 , y = 0.25, s = EPISODES[i], size=15, color='k',verticalalignment='bottom',rotation = 30,transform=ax.transAxes)

ax.set_ylabel('TIMESTEPS REQUIRED TO SOLVE',color = 'k',size = 14)
ax.set_yscale("log")
ax.legend()

fig.savefig('cartpole-v0-perf.pdf', bbox_inches='tight')

# %%
EPISODES = np.array([1998.7647058824,2512.5,2767.1724137931,768,824]).round(2)

# TIMESTEPS
NN = np.array([200,173868.735294118,315503])
NN_R =np.array([75128,526775.588235294,1301015]) 
NN_L =np.array([95756,367451,1471212,])
DRL_10 = np.array([585,1450.6176470588,6075])
DRL_40 = np.array([585,1564.9411764706,5607])

DATA = np.vstack((NN, NN_R, NN_L, DRL_10, DRL_40))
NO_OF_DATA_GRPS = DATA.shape[0] 

MIN_VALUE = DATA[:,0]
AVG_VALUE = DATA[:,1]
MAX_VALUE = DATA[:,2]
fig = plt.figure(figsize = (7,5))

ax1 = fig.add_subplot(1, 1,1)
ax1.set_title("CartPole-v0+ Environment", size = 22)
ax1.bar(range(NO_OF_DATA_GRPS) , MAX_VALUE,  alpha = 0.5, edgecolor = 'black', capsize=7 ,label = "Maximum Time Required")
ax1.bar(range(NO_OF_DATA_GRPS) , AVG_VALUE,  edgecolor = 'black', capsize=7, label = "Average Time Required" )
ax1.bar(range(NO_OF_DATA_GRPS) , MIN_VALUE,  alpha = 0.6, edgecolor = 'black', capsize=7, label = "Minimum Time Required" )

ax1.set_xticks(range(NO_OF_DATA_GRPS))
ax1.set_xticklabels(["NN", "NN-R", "NN-L", "DRL-10", "DRL-40"],rotation=0, size = 14)


for i in range(NO_OF_DATA_GRPS):
    ax1.text(x = 0.12+i/5.25 , y = 0.22, s = EPISODES[i], size=15, color='k',horizontalalignment='center',rotation = 30,transform=ax1.transAxes)

ax1.set_ylabel('TIMESTEPS REQUIRED TO SOLVE',color = 'k',size = 14)
ax1.set_yscale("log")

ax1.legend()
fig.tight_layout()
# ax.grid()
plt.show()

fig.savefig('cartpole-v0+-perf.pdf', bbox_inches='tight')

# %%
NO_OF_DATA_GRPS
# Out:
# 5

# %%
#DRL_XPLORE_CP

G0_state_space = np.array([ [0.2360316672,1.3742383032,0.6184729937,0.5916732573034365],
                            [-0.3989995848,-0.8414710999,-2.0577905945,-0.09641444776695465],

                            [ 0.2370623578,0.271071695,0.3153376817,0.5736368686237939],
                            [-0.0352701431,-0.6956335141,-2.2705015545,-0.13644832535151014 ],

                            [0.2353055425,1.4235139545,1.6791230806, 0.6348372594831899],
                            [-0.3281328653,-0.2468037026,-2.16446808, -0.09286224348604445],

                            [0.2326472081,0.2563780737,0.3426242212, 0.5770687185696715],
                            [-0.0345496729,-0.6975054061,-2.268633952,-0.08382739250804794 ],

                            [0.252849135,1.5664037853,0.8911388714,0.6631870272069906 ],
                            [-0.5421464248,-0.3850938638,-1.9472161391, -0.1053938704976374],

                            [0.2371137413,0.2875789782,0.3174211452,0.6000716751241939 ],
                            [-0.035074418,-0.5680427573,-2.2688435135,-0.11053898998741825],

                            [0.2662485977,1.2476934873,1.0013014472, 0.621602981730549],
                            [-0.2180475941,-0.4467272898,-2.2195004727,-0.09857430142654364 ],

                            [0.23223828,0.2945111971,0.3324594495, 0.5464086805338837],
                            [-0.0323520643,-0.6968305715,-2.2693948785,-0.09983494850273822 ],

                            [0.2518240101,1.1780848633,1.5536172883, 0.6019829325081905],
                            [-0.3262217888, -1.8084823289, -2.0415580526, -0.11975735947805546],

                            [0.2199965526, 0.2527790059, 0.3147363867, 0.6248245022848304],
                            [-0.0373061772, -0.6042361805, -2.2702989181,-0.10086852017533306]])


node_max_time = np.array([ 200.000,  200.000,  200.000,  200.000,  200.000,  200.000,
        200.000,  200.000,  200.000,  200.000])
node_min_time = np.array([ 150.000,  148.000,  170.000,  170.000,  125.000,  180.000,
        136.000,  185.000,  155.000,  158.000])

node_avg_time = np.array([ 197.090,  197.000,  197.790,  199.000,  190.870,  198.360,
        193.430,  199.370,  198.010,  191.370])
NO_OF_NODES = 10


fig = plt.figure(figsize = (10,10))
# fig.suptitle('DRL-XCP in CartPole-v0',fontsize = 24)
fig.subplots_adjust(hspace=3)

ax = fig.add_subplot(2, 1, 1)
ax.set_title("CartPole-v0 State Space Penetration", size = 19)

for iteration in range(4):
    for node_id in range(0,NO_OF_NODES):
        cartpos_max = G0_state_space[node_id][iteration]
        cartpos_min = G0_state_space[node_id +1][iteration]
        span = cartpos_max-cartpos_min
        ax.barh(y=node_id , width=span, left=cartpos_min, height=0.9,alpha = 0.35)

ax.axvline(x= 0, color = 'k', alpha = 0.5, linestyle='--')
ax.axvline(x=-2.6, color = 'b', alpha = 0.5, linestyle='-')
ax.axvline(x= 2.6, color = 'b', alpha = 0.5,linestyle='-')
ax.axvline(x=-2.4, color = 'b',alpha = 0.5, linestyle=':')
ax.axvline(x= 2.4, color = 'b',alpha = 0.5, linestyle=':')
ax.set_xlabel("CartPole Position", size='18')
ax.set_yticklabels([])
ax.set_yticks([])

# ax.grid()

for i in range(NO_OF_NODES):
    ax.text(x = -1.5 , y = i , s = "NODE "+str(i), size=16, color='k',horizontalalignment='center',verticalalignment='center')

ax2 = fig.add_subplot(2, 1, 2)
ax2.set_title("Time to solve = 671, Speedup = 237.11, Episodes Required = 300   ", size = 19)

for node_id in range(0,NO_OF_NODES):
    ax2.bar(node_id, node_min_time[node_id], color = cmap(node_id), alpha = .3, edgecolor = 'black', capsize=7 )
    ax2.bar(node_id, node_avg_time[node_id], color = cmap(node_id),alpha = .5, edgecolor = 'black', capsize=7 )
    ax2.bar(node_id, node_max_time[node_id], color = cmap(node_id),alpha = .1, edgecolor = 'black', capsize=7 )
    
ax2.set_ylabel('Mean Node Lifetime',color = 'k', size = 20)
ax2.set_xticklabels([])
ax2.set_xticks([])
for i in range(NO_OF_NODES):
    ax2.text(x = i, y = 50 , s = "NODE "+str(i), size=20, color='k',horizontalalignment='center',verticalalignment='center',rotation="90")

fig.tight_layout()
# ax2.grid()
plt.show()
fig.savefig('drl_xcp-state-space-v0.pdf', bbox_inches='tight')

# %%
#DRL

with open('data.csv', 'r') as f:
    G0_state_space = np.array(list(csv.reader(f, delimiter=',')),dtype=np.float)

node_max_time = np.array([ 200.000,  200.000,  200.000,  200.000,  200.000,  200.000,200.000,  200.000,  200.000,  200.000])
node_min_time = np.array([ 81.000,  67.000,  81.000,  72.000,  155.000,  81.000,  62.000,160.000,  62.000,  95.000])
node_avg_time = np.array([ 196.270,  196.080,  193.250,  194.550,  198.000,  195.160,195.050,  197.520,  193.370,  195.450])

node_avg_time = np.array([ 197.090,  197.000,  197.790,  199.000,  190.870,  198.360,
        193.430,  199.370,  198.010,  191.370])
NO_OF_NODES = 10



fig = plt.figure(figsize = (10,10))
# fig.suptitle('DRL in CartPole-v0', fontsize=24)

fig.subplots_adjust(hspace=3)

ax = fig.add_subplot(2, 1, 1)
ax.set_title("CartPole-v0 State Space Penetration",size=19)

for iteration in range(4):
    for node_id in range(0,NO_OF_NODES):
        cartpos_max = G0_state_space[node_id][iteration]
        cartpos_min = G0_state_space[node_id +1][iteration]
        span = cartpos_max-cartpos_min
        ax.barh(y=node_id , width=span, left=cartpos_min, height=0.9,alpha = 0.35)

ax.axvline(x= 0, color = 'k', alpha = 0.5, linestyle='--')
ax.axvline(x=-2.6, color = 'b', alpha = 0.5, linestyle='-')
ax.axvline(x= 2.6, color = 'b', alpha = 0.5,linestyle='-')
ax.axvline(x=-2.4, color = 'b',alpha = 0.5, linestyle=':')
ax.axvline(x= 2.4, color = 'b',alpha = 0.5, linestyle=':')
ax.set_xlabel("CartPole Position", size='18')
ax.set_yticklabels([])
ax.set_yticks([])

# ax.grid()

for i in range(NO_OF_NODES):
    ax.text(x = -1.5 , y = i , s = "NODE"+str(i), size=12, color='k',horizontalalignment='center',verticalalignment='center')

ax2 = fig.add_subplot(2, 1, 2)
ax2.set_title("Time to Solve = 1784, Speedup = 89.18, Episodes Required = 800   ", size = 19)

for node_id in range(0,NO_OF_NODES):
    ax2.bar(node_id, node_min_time[node_id], color = cmap(node_id), alpha = .3, edgecolor = 'black', capsize=7 )
    ax2.bar(node_id, node_avg_time[node_id], color = cmap(node_id),alpha = .5, edgecolor = 'black', capsize=7 )
    ax2.bar(node_id, node_max_time[node_id], color = cmap(node_id),alpha = .1, edgecolor = 'black', capsize=7 )
    
ax2.set_ylabel('Mean Node Lifetime',color = 'k', size = 20)
ax2.set_xticklabels([])
ax2.set_xticks([])
for i in range(NO_OF_NODES):
    ax2.text(x = i, y = 50 , s = "NODE "+str(i), size=20, color='k',horizontalalignment='center',verticalalignment='center', rotation=90)

fig.tight_layout()
# ax2.grid()
fig.savefig('drl-state-space-v0.pdf', bbox_inches='tight')

plt.show()
